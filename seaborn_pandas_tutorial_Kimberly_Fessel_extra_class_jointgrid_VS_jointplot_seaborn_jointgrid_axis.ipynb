# %%
import pandas as pd
import numpy as np 
from matplotlib import pyplot as plt
pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', 1000)
import seaborn as sns
df = pd.read_excel(r"C:\Users\Christ05\.VS_code_PhD_data\Pandas_Hardouvelis_Most_Frequent Words_DIOIKHTES_TtE_updated_1997_2021.xlsx")

# %%
df.head(2)
# Out:
#    ετος  οικονομια_ΤτΕ  επιδοτηση_ΤτΕ  επιτοκιο_ΤτΕ  φορο_ΤτΕ  χρεος_ΤτΕ  \
# 0  1997            104              4            80        78         28
# 1  1998            145              4            72       322         23
#
#    εε_ΤτΕ  φπα_ΤτΕ  ελλειμμα_ΤτΕ  επιδοματ_ΤτΕ  \
# 0     123        0            81             5
# 1     173       11           114             2
#
#    ειδικος φορος καταναλωσης _ΤτΕ  έσοδα ιδιωτικοποιήσεων_ΤτΕ  \
# 0                               0                           0
# 1                               0                           0
#
#    αποκρατικοπ*_ΤτΕ  ιδιωτικοποιηση_ΤτΕ  εφορια  \
# 0                 3                   0       0
# 1                 3                   3       0
#
#    ανεξαρτ αρχη δημοσ εσοδ / ααδε  δημοσιες δαπαν  πρωτογενεις δαπανες_ΤτΕ  \
# 0                               0               0                        0
# 1                               0               0                       10
#
# ...

# %% [markdown]
# (1)  Seaborn JointGrid_Vs_Jointplot_&_Seaborn_jointgrid_axis_Kimberly Fessel_ # https://www.youtube.com/watch?v=t3G078DWXBM
#
# 1.17" - 2.49" ....Creating a Jointgrid (στο μέρος μεσα έχουμε το σκατερπλοτ ενώ στα άκρα τις οριακές κατανομές ή marginal distributions)

# %%
sns.set_style('darkgrid')
g= sns.JointGrid(data=df, x = 'αποκρατικοπ*_ΤτΕ', y = 'μεταρρυθμιση_ΤτΕ')
type(g)
g.plot(sns.scatterplot, sns.histplot)

# %%
df.to_excel('saved_png_file_metaruthmisi_apokratikop.xlsx')

# %% [markdown]
# στο παραπάνω διάγραμμα φαίνονται στα άκρα οι κατανομές των μεταβλητών "αποκρατικοπ" κ "μεταρρυθμίσεις" από τα δεδομένα των Διοικητών ΤτΕ. φαίνεται οτι ειναι μικρός σχετικά ο αριθμός των παρατηρήσεων, δλδ δεν δείχνει να υπάρχει κάποια ισχυρή συσχέτιση (σχέση) μεταξύ των δύο μεταβλητών. περίπου 0-5 ειναι η στήλη με τις περισσότερες αναφορές στην αποκρατικοποιηση και 0-5 στην αναφορά για μεταρρύθμιση απο του Διοικητές της ΤτΕ.

# %% [markdown]
# (2) ...στον παρακάτω κώδικα φαίνονται σε κατανομές και συσχέτιση οι δύο μεταβλητές.

# %%
sns.set_style('darkgrid')
g= sns.JointGrid(data=df, x = 'αποκρατικοπ*_ΤτΕ', y = 'μεταρρυθμιση_ΤτΕ')
type(g)
g.plot(sns.regplot, sns.kdeplot)

# %% [markdown]
# 4.53 στο παραπάνω γραφημα φαινεται μια μικρή έως και αρνητική κλίση ως προς τις μεταρρυθμίσεις κ τις αποκρατικοποιήσεις.

# %%
df.loc[0:25, ["αποκρατικοπ*_ΤτΕ","μεταρρυθμιση_ΤτΕ"]].describe()
# Out:
#        αποκρατικοπ*_ΤτΕ  μεταρρυθμιση_ΤτΕ
# count         25.000000         25.000000
# mean           8.880000          8.360000
# std            6.851521          9.064031
# min            0.000000          0.000000
# 25%            3.000000          0.000000
# 50%            6.000000          7.000000
# 75%           13.000000         14.000000
# max           24.000000         36.000000

# %% [markdown]
# Για να το σώσω και να το κάνω εξαγωγή το παρακάτω αρχείο προσοχή στον κώδικα. Πρώτα ονομάζεις την μεταβλητή που περιγράφει τα αποτελέσματα κ στην συνέχεια τα εξάγεις σε εξελ μορφή ή csv ή οτι άλλο θέλεις. ΟΛΟΣ Ο ΚΩΔΙΚΑΣ ΑΚΟΛΟΥΘΕΙ!!!
#
# !!! αν θελεις να ξαναγραψεις το αρχειο προσοχή πρεπει να μετανομάσεις το αρχείο στο pathway γιατι δεν γράφει πάνω στο άλλο!!!

# %%
df_apokratikop_metarrithm = df.loc[0:25, ["αποκρατικοπ*_ΤτΕ","μεταρρυθμιση_ΤτΕ"]].describe()
df_apokratikop_metarrithm.to_excel(r'C:\Users\Christ05\.VS_code_PhD\_Kimberly_Fessel_apokratikop_metarrithm.xlsx', index = False)

# %% [markdown]
# (3) .....5.47" η αλλαγή στον κώδικα (φαίνεται στην επόμενη γραμμή) κ το νέο γράφημα...δείχνει τις τιμές πιο άμεσα σε κάθε άξοναα

# %%
sns.set_style('darkgrid')
g= sns.JointGrid(data=df, x = 'αποκρατικοπ*_ΤτΕ', y = 'μεταρρυθμιση_ΤτΕ')
type(g)
g.plot_joint(sns.regplot)
g.plot_marginals(sns.kdeplot, fill = True)

# %%
type(g.ax_marg_x)
# Out:
# matplotlib.axes._subplots.AxesSubplot

# %%
g = sns.JointGrid()
data = df
x, y = ['αποκρατικοπ*_ΤτΕ', 'μεταρρυθμιση_ΤτΕ']

# %% [markdown]
# (4) ...αλλαγή στο 8.27" , στον κώδικα και τονίζει τους άξονες x, y. # στην δική μου περιπτωση ΔΕΝ αναγνωρίζει τις μεταβλητές μου που θα μπούνε κ στο πλάι.

# %%
g = sns.JointGrid()  
data=df
x, y = 'αποκρατικοπ*_ΤτΕ', 'μεταρρυθμιση_ΤτΕ'


sns.regplot(x=x, y=y, ax=g.ax_joint)
sns.kdeplot(x=x, ax=g.ax_marg_x)
sns.histplot(y=y, ax=g.ax_marg_y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6560\1079489325.py in <module>
#       4
#       5
# ----> 6 sns.regplot(x=x, y=y, ax=g.ax_joint)
#       7 sns.kdeplot(x=x, ax=g.ax_marg_x)
#       8 sns.histplot(y=y, ax=g.ax_marg_y)
#
# c:\Users\Christ05\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ...

# %% [markdown]
# 9.46", hue for categorical varibles...

# %%
sns.set_style('darkgrid')
g= sns.JointGrid(data=df, x = 'αποκρατικοπ*_ΤτΕ', y = 'μεταρρυθμιση_ΤτΕ', hue = 'πολιτικη θεση κυβερνησης')
g.plot(sns.scatterplot, sns.kdeplot)
sns.regplot(x=x, y=y, ax=g.ax_joint)
sns.kdeplot(x=x, ax=g.ax_marg_x, hue='πολιτικη θεση κυβερνησης')
sns.histplot(y=y, ax=g.ax_marg_y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13012\78414115.py in <module>
#       1 sns.set_style('darkgrid')
# ----> 2 g= sns.JointGrid(data=df, x = 'αποκρατικοπ*_ΤτΕ', y = 'μεταρρυθμιση_ΤτΕ', hue = 'πολιτικη θεση κυβερνησης')
#       3 g.plot(sns.scatterplot, sns.kdeplot)
#       4 sns.regplot(x=x, y=y, ax=g.ax_joint)
#       5 sns.kdeplot(x=x, ax=g.ax_marg_x, hue='πολιτικη θεση κυβερνησης')
#
# c:\Users\Christ05\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ...

# %% [markdown]
# (5)....10.59"

# %%
sns.set_style('darkgrid')
g= sns.JointGrid(data=df, x = 'αποκρατικοπ*_ΤτΕ', y = 'μεταρρυθμιση_ΤτΕ', hue='πολιτικος τυπος κυβερνησης')
g.plot(sns.scatterplot, sns.kdeplot);
# Out:
# c:\Users\Christ05\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:316: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   warnings.warn(msg, UserWarning)
# c:\Users\Christ05\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:316: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   warnings.warn(msg, UserWarning)

# %%
sns.set_style('darkgrid')
g= sns.JointGrid(data=df, x = 'αποκρατικοπ*_ΤτΕ', y = 'μεταρρυθμιση_ΤτΕ', hue='πολιτικη θεση κυβερνησης')
g.plot(sns.scatterplot, sns.kdeplot)

# %% [markdown]
# 11.12" ...............Styling

# %%
sns.set_style('darkgrid')
g= sns.JointGrid(data=df, x = 'αποκρατικοπ*_ΤτΕ', y = 'μεταρρυθμιση_ΤτΕ')
g.plot(sns.scatterplot, sns.histplot, alpha= 0.8 , edgecolor='black');

# %% [markdown]
# 12.20"....

# %%
sns.set_style('darkgrid')
g= sns.JointGrid(data=df, x = 'αποκρατικοπ*_ΤτΕ', y = 'μεταρρυθμιση_ΤτΕ')
g.plot_joint(sns.regplot, line_kws={'color':'black'})
g.plot_marginals(sns.kdeplot);

# %% [markdown]
# 12.42"

# %%
sns.set_style('darkgrid')
g= sns.JointGrid(data=df, x = 'αποκρατικοπ*_ΤτΕ', y = 'μεταρρυθμιση_ΤτΕ')
g.plot_joint(sns.regplot, line_kws={'color':'black'})
g.plot_marginals(sns.kdeplot, fill=True, color='purple');

# %% [markdown]
# 13.19"_ ονοματοδοσία στους άξονες και μεγεθος χαρακτήρων

# %%
sns.set_style('darkgrid')
g= sns.JointGrid(data=df, x = 'αποκρατικοπ*_ΤτΕ', y = 'μεταρρυθμιση_ΤτΕ')
g.plot(sns.scatterplot, sns.histplot)
g.set_axis_labels(xlabel = 'αποκρατικοποιησεις_ΤτΕ', ylabel='μεταρρυθμιση', fontsize=14);

# %% [markdown]
# 13:50"....σωσε την εικονα (εικονοδιο κτλ)

# %%
sns.set_style('darkgrid')
g= sns.JointGrid(data=df, x = 'αποκρατικοπ*_ΤτΕ', y = 'μεταρρυθμιση_ΤτΕ')
g.plot(sns.scatterplot, sns.histplot)
g.set_axis_labels(xlabel = 'αποκρατικοποιησεις_ΤτΕ', ylabel='μεταρρυθμιση', fontsize=14)
g.savefig('Joint_grid_verson_1.png')

# %% [markdown]
# 14.00" ......ανοίγω το αρχείο που νωρίτερα ειχα σωσει.

# %%
# !open Joint_grid_verson_1
# Out:
# 'open' is not recognized as an internal or external command,
# operable program or batch file.

# %%
6 different types of "kind"...scatter / kde / reg / hex / hist / resid

# %%
sns.set_style('darkgrid')
sns.jointplot(x='ονε_ΤτΕ', y='ελλειμμα_ΤτΕ', data=df)

# %%
sns.set_style('darkgrid')
sns.jointplot(x='ονε_ΤτΕ', y='ελλειμμα_ΤτΕ', data=df, kind='kde')

# %%
sns.set_style('darkgrid')
sns.jointplot(x='ονε_ΤτΕ', y='ελλειμμα_ΤτΕ', data=df, kind='reg')

# %%
sns.set_style('darkgrid')
sns.jointplot(x='ονε_ΤτΕ', y='ελλειμμα_ΤτΕ', data=df, kind='hist')

# %%
type(get_ipython) = sns.pairgrid()
get_ipython.plot_joint(sns.kdeplot, color='gray', levels=5)
# Out:
#   File "C:\Users\Christ05\AppData\Local\Temp\ipykernel_12396\1817433168.py", line 1
#     type(get_ipython) = sns.pairgrid()
#     ^
# SyntaxError: cannot assign to function call

# %% [markdown]
# #6.33" Categorical Variable

# %%
sns.set_style('darkgrid')
sns.jointplot(x='ονε_ΤτΕ', y='ελλειμμα_ΤτΕ', data=df, hue='πολιτικη θεση κυβερνησης', kind='kde')

# %% [markdown]
# #8.01" Advanced Styling

# %%
sns.set_style('darkgrid')
sns.jointplot(x='ονε_ΤτΕ', y='ελλειμμα_ΤτΕ', data=df, hue='πολιτικη θεση κυβερνησης', color='green')

# %%
sns.set_style('darkgrid')
sns.jointplot(x='ονε_ΤτΕ', y='ελλειμμα_ΤτΕ', data=df, hue='πολιτικη θεση κυβερνησης', height=8, space=0.1 , ratio=5)

# %% [markdown]
# 10.11" joint keywords and marginal keywords #11.26" @joint_kws

# %%
sns.set_style('darkgrid')
sns.jointplot(x='ονε_ΤτΕ', y='ελλειμμα_ΤτΕ', data=df, kind='reg', joint_kws= { 'ci': None, 'order': 2})

# %%
sns.set_style('darkgrid')
sns.jointplot(x='χρεος_ΤτΕ', y='ελλειμμα_ΤτΕ', data=df, kind='reg', joint_kws= { 'ci': None, 'order': 2})

# %%
sns.set_style('darkgrid')
sns.jointplot(x='ονε_ΤτΕ', y='χρεος_ΤτΕ', data=df, kind='reg', joint_kws= { 'ci': None, 'order': 2})

# %%
sns.set_style('darkgrid')
sns.jointplot(x='αποκρατικοπ*_ΤτΕ', y='μεταρρυθμιση_ΤτΕ', data=df, kind='reg', joint_kws= { 'ci': None, 'order': 2})

# %%
sns.set_style('darkgrid')
sns.lineplot(y='ελλειμμα_ΤτΕ', x='ετος', data=df, ci=None)
# Out:
# <AxesSubplot:xlabel='ετος', ylabel='ελλειμμα_ΤτΕ'>

# %%
sns.set_style('darkgrid')
sns.lineplot(y='χρεος_ΤτΕ', x='ετος', data=df, ci=None)
# Out:
# <AxesSubplot:xlabel='ετος', ylabel='χρεος_ΤτΕ'>

# %%
sns.set_style('darkgrid')
sns.jointplot(x='ονε_ΤτΕ', y='ελλειμμα_ΤτΕ', data=df, kind='reg', marginal_kws= {'color': 'xkcd:golden'})

# %%
sns.set_style('darkgrid')
sns.jointplot(x='ονε_ΤτΕ', y='ελλειμμα_ΤτΕ', data=df, kind='kde', marginal_kws= {'color': 'blue', 'shade': True})

# %%
sns.kdeplot('μεταρρυθμιση_ΤτΕ','αποκρατικοπ*_ΤτΕ', shade=True, shade_lowest=False, cbar=True, data=df)
# Out:
# c:\Users\Christ05\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# c:\Users\Christ05\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:1718: UserWarning: `shade_lowest` is now deprecated in favor of `thresh`. Setting `thresh=0.05`, but please update your code.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='μεταρρυθμιση_ΤτΕ', ylabel='αποκρατικοπ*_ΤτΕ'>

# %%
import pandas as pd
import numpy as np 
from matplotlib import pyplot as plt
pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', 1000)
import seaborn as sns
df = pd.read_excel(r"C:\Users\Christ05\.VS_code_PhD_data\Pandas_Hardouvelis_VOULI_Frequent_words.xlsx")

# %%
sns.set_style('darkgrid')
sns.jointplot(x='ονε', y='ελλειμμα', data=df, kind='reg', joint_kws= { 'ci': None, 'order': 2})

# %%
sns.set_style('darkgrid')
sns.jointplot(x='χρεος', y='ελλειμμα', data=df, kind='reg', joint_kws= { 'ci': None, 'order': 2})

# %%
df.head(2)
# Out:
#    ετος  οικονομια  επιδοτηση  επιτοκιο  φορο  χρεος  εε  φπα  ελλειμμα  \
# 0  2000          7         45         0   284      0  28   32         0
# 1  2001          6         43         0   295      1  96    5         0
#
#    αποκρατικοπ*  επιδοματ  ιδιωτικοποιηση  εφορια  δημοσιο χρεος  επιδομα  \
# 0             0         1              36       1              0        4
# 1            27         1               7       3              1        3
#
#    χρεοκοπια  επιτοκιο.1  δραχμη  ευρωζωνη  εθνικο νομισμα  ονε  Grexit  \
# 0          0           0       0         0               0   11       0
# 1          0           0       0         0               0    7       0
#
#    εξοδος απο ευρωζ  τραπεζα  τραπεζικο συστημα  δανειο  καταθεσεις  συνταξη  \
# 0                 0       68                  0       6           0       20
# 1                 0       30                  1      13           0       21
#
# ...

# %%
sns.set_style('darkgrid')
sns.jointplot(x='ιδιωτικοποιηση', y='αποκρατικοπ*', data=df, hue='πολιτικη θεση κυβερνησης', height=8, space=0.1 , ratio=5)

# %%
sns.set_style('darkgrid')
sns.jointplot(x='ιδιωτικοποιηση', y='αποκρατικοπ*', data=df, hue='τυπος κυβερνησης')

# %%
sns.set_style('darkgrid')
sns.jointplot(x='ιδιωτικοποιηση', y='αποκρατικοπ*', data=df, kind='reg', joint_kws= { 'ci': None, 'order': 2})
